# %%
#basics
print("\n Basic Statistical Description:")
print(df.describe())
print("\n Median of each column:")
print(df.median())
print("\nStandard Deviation of each column:")
print(df.std())
print("Min and Max values of each column:")
print("Minimum values:\n", df.min())
print("\nMaximum values:\n", df.max())
# Out:
#  Basic Statistical Description:
#                 Age  Menstrual_Irregularity  Chronic_Pain_Level  \
# count  10000.000000            10000.000000        10000.000000
# mean      33.699900                0.697500            5.038747
# std        9.228649                0.459364            2.070441
# min       18.000000                0.000000            0.000000
# 25%       26.000000                0.000000            3.671697
# 50%       34.000000                1.000000            5.036046
# 75%       42.000000                1.000000            6.397315
# max      100.000000                1.000000           56.100000
#
#        Hormone_Level_Abnormality   Infertility           BMI     Diagnosis
# count               10000.000000  10000.000000  10000.000000  10000.000000
# mean                    0.591100      0.298300     23.056671      0.407900
# std                     0.491655      0.457535      3.896133      0.491469
# ...

# %%
#variable datatype
import pandas as pd
df = pd.read_csv('endodatasetrevised1.csv')
print(df.head())
print("\ndata types:")
print(df.dtypes)
print("\nsummary")
print(df.info())
# Out:
#    Age  Menstrual_Irregularity  Chronic_Pain_Level  Hormone_Level_Abnormality  \
# 0   24                       1            8.361531                          0
# 1   37                       1            4.995508                          0
# 2   46                       1            3.363996                          1
# 3   32                       1            5.246037                          0
# 4   28                       1           35.100000                          1
#
#    Infertility        BMI  Diagnosis
# 0            0  19.451314          0
# 1            0  22.388436          0
# 2            0  21.320443          0
# 3            0  20.177715          1
# 4            0  23.538103          1
#
# data types:
# Age                            int64
# Menstrual_Irregularity         int64
# Chronic_Pain_Level           float64
# Hormone_Level_Abnormality      int64
# Infertility                    int64
# BMI                          float64
# ...

# %%
#non graph uni
import pandas as pd
df = pd.read_csv('endodatasetrevised1.csv')
for column in df.columns:
    print(f"\n{column} ")
    # Mean
    mean_val = df[column].mean()
    print("Mean:", mean_val)
    # Median
    median_val = df[column].median()
    print("Median:", median_val)
    # Mode
    mode_val = df[column].mode().tolist()
    print("Mode:", mode_val)
    # Quartiles
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    print("1st Quartile (Q1):", q1)
    print("3rd Quartile (Q3):", q3)
    # Range
    range_val = df[column].max() - df[column].min()
    print("Range:", range_val)
# Out:
# Age
# Mean: 33.6999
# Median: 34.0
# Mode: [34]
# 1st Quartile (Q1): 26.0
# 3rd Quartile (Q3): 42.0
# Range: 82
#
# Menstrual_Irregularity
# Mean: 0.6975
# Median: 1.0
# Mode: [1]
# 1st Quartile (Q1): 0.0
# 3rd Quartile (Q3): 1.0
# Range: 1
#
# Chronic_Pain_Level
# Mean: 5.038746893567514
# Median: 5.0359424945
# Mode: [0.0]
# 1st Quartile (Q1): 3.67154184525
# 3rd Quartile (Q3): 6.397643427749999
# Range: 56.1
#
# Hormone_Level_Abnormality
# Mean: 0.5911
# Median: 1.0
# Mode: [1]
# 1st Quartile (Q1): 0.0
# 3rd Quartile (Q3): 1.0
# Range: 1
#
# Infertility
# Mean: 0.2983
# Median: 0.0
# Mode: [0]
# 1st Quartile (Q1): 0.0
# 3rd Quartile (Q3): 1.0
# Range: 1
#
# BMI
# Mean: 23.056671089358936
# Median: 23.03818527
# Mode: [15.0]
# 1st Quartile (Q1): 20.33028367
# 3rd Quartile (Q3): 25.71619956
# Range: 30.0
#
# Diagnosis
# Mean: 0.4079
# Median: 0.0
# Mode: [0]
# 1st Quartile (Q1): 0.0
# 3rd Quartile (Q3): 1.0
# Range: 1

# %%
#bivariate analysis
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('endodatasetrevised1.csv')
#num vs num
plt.figure(figsize=(6, 4))
sns.scatterplot(x='Age', y='Chronic_Pain_Level', data=df)
plt.title("Age vs Chronic Pain Level")
plt.xlabel("Age")
plt.ylabel("Chronic Pain Level")
plt.tight_layout()
plt.show()
#cat vs caty
grouped_counts = df.groupby(['Diagnosis', 'Hormone_Level_Abnormality']).size().unstack()
grouped_counts.plot(kind='bar', stacked=True, colormap='Set2')
plt.title("Diagnosis vs Hormone Level Abnormality (Stacked Bar)")
plt.xlabel("Diagnosis (0 = No Endometriosis, 1 = Endometriosis)")
plt.ylabel("Count")
plt.legend(title="Hormone Level Abnormality")
plt.tight_layout()
plt.show()

# %%
#graphuni
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('endodatasetrevised1.csv')
#histo
df.hist(figsize=(10, 8), bins=20, color='skyblue', edgecolor='black')
plt.suptitle('Histograms of Numerical Features')
plt.tight_layout()
plt.show()
#boxplot
for col in df.select_dtypes(include=['int64', 'float64']).columns:
    plt.figure(figsize=(6, 4))
    sns.boxplot(y=df[col], color='lightgreen')
    plt.title(f'Boxplot of {col}')
    plt.tight_layout()
    plt.show()
#heat map
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()
#bargraph
categorical_cols = ['Diagnosis', 'Infertility', 'Hormone_Level_Abnormality', 'Menstrual_Irregularity']
for col in categorical_cols:
    plt.figure(figsize=(5, 4))
    sns.countplot(x=col, data=df, palette='pastel')
    plt.title(f'Bar Graph of {col}')
    plt.tight_layout()
    plt.show()
# Out:
# <ipython-input-13-41e3066a18bb>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, palette='pastel')
# <ipython-input-13-41e3066a18bb>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, palette='pastel')
# <ipython-input-13-41e3066a18bb>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, palette='pastel')
# <ipython-input-13-41e3066a18bb>:28: FutureWarning:
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('endodatasetrevised1.csv')
cols_to_transform = ['Age', 'BMI', 'Chronic_Pain_Level']
for col in cols_to_transform:
    df[f'{col}_log'] = np.log(df[col] + 1)
    df[f'{col}_norm'] = (df[col] - df[col].min()) / (df[col].max() - df[col].min())
transformed_cols = [col for col in df.columns if col.endswith('_log') or col.endswith('_norm')]
print("Transformed Columns Preview:")
print(df[transformed_cols].head())
# Out:
# Transformed Columns Preview:
#     Age_log  Age_norm   BMI_log  BMI_norm  Chronic_Pain_Level_log  \
# 0  3.218876  0.073171  3.018047  0.148377                2.236609
# 1  3.637586  0.231707  3.152242  0.246281                1.791010
# 2  3.850148  0.341463  3.105503  0.210681                1.473388
# 3  3.496508  0.170732  3.052949  0.172591                1.831947
# 4  3.367296  0.121951  3.200227  0.284603                3.586293
#
#    Chronic_Pain_Level_norm
# 0                 0.149047
# 1                 0.089046
# 2                 0.059964
# 3                 0.093512
# 4                 0.625668

# %%
#missing value treatment
print(df.isnull().sum())
# Out:
# Age                          0
# Menstrual_Irregularity       0
# Chronic_Pain_Level           0
# Hormone_Level_Abnormality    0
# Infertility                  0
# BMI                          0
# Diagnosis                    0
# dtype: int64

# %%
# Outlier Check
import pandas as pd

df = pd.read_csv('endodatasetrevised.csv')
numerical_cols = ['Age', 'Chronic_Pain_Level', 'BMI']

for col in numerical_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

    print(f"\nColumn: {col}")
    print(f"Outliers Found: {len(outliers)}")
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

for col in numerical_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df[col] = df[col].clip(lower=lower_bound, upper=upper_bound)

    print(f"Outliers in '{col}' have been treated (clipped to IQR bounds).")
# Out:
# Column: Age
# Outliers Found: 1
#
# Column: Chronic_Pain_Level
# Outliers Found: 2
#
# Column: BMI
# Outliers Found: 30
# Outliers in 'Age' have been treated (clipped to IQR bounds).
# Outliers in 'Menstrual_Irregularity' have been treated (clipped to IQR bounds).
# Outliers in 'Chronic_Pain_Level' have been treated (clipped to IQR bounds).
# Outliers in 'Hormone_Level_Abnormality' have been treated (clipped to IQR bounds).
# Outliers in 'Infertility' have been treated (clipped to IQR bounds).
# Outliers in 'BMI' have been treated (clipped to IQR bounds).
# Outliers in 'Diagnosis' have been treated (clipped to IQR bounds).

# %%
#correlation analysis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('endodatasetrevised.csv')
numeric_df = df.select_dtypes(include=['int64', 'float64'])
correlation_matrix = numeric_df.corr()
print("Correlation Matrix:\n")
print(correlation_matrix)
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Correlation Matrix:
#
#                                 Age  Menstrual_Irregularity  \
# Age                        1.000000               -0.009149
# Menstrual_Irregularity    -0.009149                1.000000
# Chronic_Pain_Level        -0.011857               -0.002747
# Hormone_Level_Abnormality -0.003375                0.014647
# Infertility                0.013505               -0.012202
# BMI                       -0.012886                0.005368
# Diagnosis                 -0.010538                0.095197
#
#                            Chronic_Pain_Level  Hormone_Level_Abnormality  \
# Age                                 -0.011857                  -0.003375
# Menstrual_Irregularity              -0.002747                   0.014647
# Chronic_Pain_Level                   1.000000                   0.000578
# Hormone_Level_Abnormality            0.000578                   1.000000
# Infertility                          0.006280                   0.003890
# ...

# %%
#pca
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler#normalise
df = pd.read_csv('endodataset.csv')
X = df[['Age', 'Chronic_Pain_Level', 'BMI']]
# Scale the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
pca = PCA(n_components=2)  #2 dimensions
X_pca = pca.fit_transform(X_scaled)
print("Original shape:", X.shape)
print("After PCA:", X_pca.shape)
# Out:
# Original shape: (10000, 3)
# After PCA: (10000, 2)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler

# Step 1: Load dataset
df = pd.read_csv('endodatasetrevised1.csv')

# Step 2: Handle missing values
df.fillna(df.mean(numeric_only=True), inplace=True)

# Step 3: Define features (X) and target (y)
X = df.drop('Diagnosis', axis=1)
y = df['Diagnosis']

# Step 4: Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 5: Apply SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_scaled, y)

# Step 6: Split the data
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Step 7: Train logistic regression model
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# Step 8: Predict and evaluate
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.5977205571971296
#
# Confusion Matrix:
#  [[693 550]
#  [403 723]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.56      0.59      1243
#            1       0.57      0.64      0.60      1126
#
#     accuracy                           0.60      2369
#    macro avg       0.60      0.60      0.60      2369
# weighted avg       0.60      0.60      0.60      2369

# %% [markdown]
# # New Section

# %%
import joblib

# Save the logistic regression model
joblib.dump(model, 'endometriosis_model.pkl')

# You can also save the scaler if needed later
joblib.dump(scaler, 'scaler.pkl')

print("Model and scaler saved successfully!")
# Load the trained model and scaler
loaded_model = joblib.load('logistic_model.pkl')
loaded_scaler = joblib.load('scaler.pkl')

# Step 1: Prepare new patient data (must match training features exactly)
# These are the same features used when training the model
new_data = pd.DataFrame({
    'Age': [29],
    'Menstrual_Irregularity': [1],
    'Chronic_Pain_Level': [3],
    'Hormone_Level_Abnormality': [1],
    'Infertility': [0],
    'BMI': [24]
})

#  Step 2: Apply the same scaling as training
new_data_scaled = loaded_scaler.transform(new_data)

# Step 3: Predict
prediction = loaded_model.predict(new_data_scaled)

# Step 4: Convert prediction to human-readable label
prediction_label = 'Positive for Endometriosis' if prediction[0] == 1 else 'Negative for Endometriosis'

# Step 5: Output
print(f"🩺 Prediction: {prediction_label}")
# Out:
# Model and scaler saved successfully!
# 🩺 Prediction: Positive for Endometriosis

# %%
import pandas as pd
import joblib
import joblib

# Save the trained model
joblib.dump(model, 'logistic_model.pkl')

# Save the scaler
joblib.dump(scaler, 'scaler.pkl')
import pandas as pd
import joblib

# Load the saved model and scaler
loaded_model = joblib.load('logistic_model.pkl')
loaded_scaler = joblib.load('scaler.pkl')

# Sample new input (match your original features exactly!)
new_data = pd.DataFrame({
    'Age': [29],
    'Menstrual_Irregularity': [1],
    'Chronic_Pain_Level': [3],
    'Hormone_Level_Abnormality': [1],
    'Infertility': [0],
    'BMI': [24]
})

# Apply the same scaler
new_data_scaled = loaded_scaler.transform(new_data)

# Make prediction
prediction = loaded_model.predict(new_data_scaled)
label = 'Positive for Endometriosis' if prediction[0] == 1 else 'Negative for Endometriosis'

print(f" Prediction: {label}")
# Out:
#  Prediction: Positive for Endometriosis
